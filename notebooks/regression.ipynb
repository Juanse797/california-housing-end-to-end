# %%
import sys

assert sys.version_info >= (3, 10)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
#Configuracion por defecto para los graficos
plt.rc('font', size=12)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=12)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
#Download and prepare the data
data_root= "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# %%
lifesat
# Out:
#            Country  GDP per capita (USD)  Life satisfaction
# 0           Russia          26456.387938                5.8
# 1           Greece          27287.083401                5.4
# 2           Turkey          28384.987785                5.5
# 3           Latvia          29932.493910                5.9
# 4          Hungary          31007.768407                5.6
# 5         Portugal          32181.154537                5.4
# 6           Poland          32238.157259                6.1
# 7          Estonia          35638.421351                5.7
# 8            Spain          36215.447591                6.3
# 9         Slovenia          36547.738956                5.9
# 10       Lithuania          36732.034744                5.9
# 11          Israel          38341.307570                7.2
# 12           Italy          38992.148381                6.0
# 13  United Kingdom          41627.129269                6.8
# 14          France          42025.617373                6.5
# 15     New Zealand          42404.393738                7.3
# 16          Canada          45856.625626                7.4
# 17         Finland          47260.800458                7.6
# 18         Belgium          48210.033111                6.9
# 19       Australia          48697.837028                7.3
# 20          Sweden          50683.323510                7.3
# 21         Germany          50922.358023                7.0
# 22         Austria          51935.603862                7.1
# 23         Iceland          52279.728851                7.5
# 24     Netherlands          54209.563836                7.4
# 25         Denmark          55938.212809                7.6
# 26   United States          60235.728492                6.9

# %%
# Visualize the data
plt.scatter(X, y)
plt.grid(True)
plt.axis([23_500, 62_500, 4, 9])
plt.xlabel("GDP")
plt.ylabel("Life satisfacion")

plt.show()

# %%
lifesat.plot(kind='scatter', grid=True, 
        x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

# %%
# Select a linear model
model = LinearRegression()

#Train the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make a prediction for Puerto Rico
X_new = [[33_442.8]] 
print(model.predict(X_new))
# Out:
# [[6.01610329]]
# /home/sebastian/miniconda3/envs/mlops/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
